# %%
#do the same for superbolts
#include correlation between power and freq

# %%
#correlation heatmap

# %%
import pandas as pd

df = pd.read_csv("../relevant csvs/Biogeochemistry power vector.csv")

corr_matrix = df.corr(method='spearman')

# extracting the correlation coefficients between "Power (J)" and the other columns
corr_power = corr_matrix.loc["Power (J)", :]

print(" ")
print("Spearman correlation of lightning power:")
print(corr_power)

import pandas as pd

df = pd.read_csv("../postprocessed/new vector.csv")

corr_matrix = df.corr(method='spearman')

# extracting the correlation coefficients between "Power (J)" and the other columns
corr_power = corr_matrix.loc["Power (J)", :]

print(" ")
print("Spearman correlation of lightning power:")
print(corr_power)
# Out:
#
# Spearman correlation of lightning power:
# Latitude         -0.060289
# Longitude         0.051525
# Power (J)         1.000000
# Salinity         -0.017378
# Temperature       0.012366
# Acidity          -0.002587
# Alkalinity       -0.054006
# Carbon           -0.112477
# tsi_1au           0.306620
# tsi_true_earth    0.065655
# Alk/Sal          -0.107172
# Name: Power (J), dtype: float64
#
# Spearman correlation of lightning power:
# Latitude      -0.060289
# Longitude      0.051525
# Power (J)      1.000000
# Salinity      -0.017378
# Temperature    0.012366
# Acidity       -0.002587
# Alkalinity    -0.054006
# Carbon        -0.112477
# Name: Power (J), dtype: float64

# %%
import pandas as pd

df = pd.read_csv("../relevant csvs/Biogeochemistry frequency vector with tsi.csv")

# assuming your dataframe is called df
corr_matrix = df.corr(method='pearson')

# extracting the correlation coefficients between "Power (J)" and the other columns
corr_power = corr_matrix.loc["Count", :]

print("Pearson correlation of lightning frequency:")
print(corr_power)

corr_matrix = df.corr(method='spearman')

# extracting the correlation coefficients between "Power (J)" and the other columns
corr_power = corr_matrix.loc["Count", :]

print(" ")
print("Spearman correlation of lightning frequency:")
print(corr_power)
# Out:
# Pearson correlation of lightning frequency:
# Latitude         -0.147408
# Longitude         0.293781
# Count             1.000000
# Salinity          0.301111
# Temperature       0.315643
# Acidity          -0.151787
# Carbon            0.218228
# Alkalinity        0.255626
# Precipitation     0.038087
# tsi_1au          -0.022518
# tsi_true_earth    0.134367
# Alk/Sal           0.027854
# Name: Count, dtype: float64
#
# Spearman correlation of lightning frequency:
# Latitude         -0.226683
# Longitude         0.413586
# Count             1.000000
# Salinity          0.420734
# Temperature       0.401126
# Acidity          -0.158041
# Carbon            0.302464
# Alkalinity        0.348502
# Precipitation     0.231015
# tsi_1au           0.021114
# tsi_true_earth    0.146490
# Alk/Sal           0.151983
# Name: Count, dtype: float64

# %%
import pandas as pd

df = pd.read_csv("../postprocessed/Biogeochemistry superbolts power vector.csv")

# assuming your dataframe is called df
corr_matrix = df.corr(method='pearson')

# extracting the correlation coefficients between "Power (J)" and the other columns
corr_power = corr_matrix.loc["Power (J)", :]

print("Pearson correlation of superbolt power:")
print(corr_power)

corr_matrix = df.corr(method='spearman')

# extracting the correlation coefficients between "Power (J)" and the other columns
corr_power = corr_matrix.loc["Power (J)", :]

print(" ")
print("Spearman correlation of superbolt power:")
print(corr_power)
# Out:
# Pearson correlation of superbolt power:
# Latitude       0.038013
# Longitude     -0.028186
# Power (J)      1.000000
# Sodium        -0.063428
# Temperature    0.030547
# pH            -0.065138
# Carbon        -0.054554
# Alkalinity    -0.047555
# Name: Power (J), dtype: float64
#
# Spearman correlation of superbolt power:
# Latitude       0.021810
# Longitude     -0.063737
# Power (J)      1.000000
# Sodium        -0.075680
# Temperature    0.032278
# pH            -0.109712
# Carbon        -0.088780
# Alkalinity    -0.062414
# Name: Power (J), dtype: float64

# %%
import pandas as pd

df = pd.read_csv("../postprocessed/Biogeochemistry superbolts frequency vector.csv")

# assuming your dataframe is called df
corr_matrix = df.corr(method='pearson')

# extracting the correlation coefficients between "Power (J)" and the other columns
corr_power = corr_matrix.loc["Count", :]

print("Pearson correlation of superbolt frequency:")
print(corr_power)

corr_matrix = df.corr(method='spearman')

# extracting the correlation coefficients between "Power (J)" and the other columns
corr_power = corr_matrix.loc["Count", :]

print(" ")
print("Spearman correlation of superbolt frequency:")
print(corr_power)
# Out:
# Pearson correlation of superbolt frequency:
# Unnamed: 0    -0.213211
# Latitude      -0.058679
# Longitude      0.178418
# Count          1.000000
# Sodium         0.162936
# Temperature    0.208556
# pH            -0.069317
# Carbon         0.127768
# Alkalinity     0.156853
# Name: Count, dtype: float64
#
# Spearman correlation of superbolt frequency:
# Unnamed: 0    -0.269941
# Latitude      -0.011844
# Longitude      0.143022
# Count          1.000000
# Sodium         0.130891
# Temperature    0.094749
# pH             0.023728
# Carbon         0.100298
# Alkalinity     0.121225
# Name: Count, dtype: float64

# %%
#combined correlation heatmaps

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = pd.read_csv("corrtemp.csv",index_col=0)

# creating a heatmap of the correlation matrix
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)

# displaying the plot
plt.show()

# %%
import pandas as pd
from scipy.stats import pearsonr

# assuming your dataframe is called df
corr_coef, p_value = pearsonr(df["Count"], df["Sodium"])

print(f"Pearson correlation coefficient between 'Power (J)' and 'Sodium': {corr_coef}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient between 'Power (J)' and 'Sodium': 0.16293623670481702
# P-value: 4.590589508048955e-06

# %%
import pandas as pd
from scipy.stats import spearmanr

# assuming your dataframe is called df
corr_coef, p_value = spearmanr(df["Count"], df["Sodium"])

print(f"Pearson correlation coefficient between 'Power (J)' and 'Sodium': {corr_coef}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient between 'Power (J)' and 'Sodium': 0.13089103196941315
# P-value: 0.00024012288258694865

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../RELEVANT CSVS/frequency for correlation.csv")
df = df.rename(columns={"Power (J)_mean": "Mean (J)"})
df = df.rename(columns={"Power (J)_sum": "Total (J)"})
column_to_move = df.pop(df.columns[3])
column_to_move2 = df.pop(df.columns[10])
column_to_move3 = df.pop(df.columns[10])

# insert the removed column at the end of the dataframe
df.insert(len(df.columns), column_to_move.name, column_to_move)
df.insert(len(df.columns), column_to_move2.name, column_to_move2)
df.insert(len(df.columns), column_to_move3.name, column_to_move3)

corr_matrix = df.corr(method='spearman')
# creating a heatmap of the correlation matrix
fig, ax = plt.subplots(figsize=(10, 8))

# plot the heatmap using the created figure and axis objects
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, ax=ax)

# displaying the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../RELEVANT CSVS/POWER VECTOR.csv")
column_to_move = df.pop(df.columns[4])

# insert the removed column at the end of the dataframe
df.insert(len(df.columns), column_to_move.name, column_to_move)

corr_matrix = df.corr(method='spearman')
# creating a heatmap of the correlation matrix
fig, ax = plt.subplots(figsize=(10, 8))

# plot the heatmap using the created figure and axis objects
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, ax=ax)

# displaying the plot
plt.show()

# %%
#correlate count to power, correlate power to precipitation
