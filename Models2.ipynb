# %%
import pandas as pd

df = pd.read_csv('../relevant csvs/Frequency for correlation.csv')
df = df.dropna()
num_columns = df.shape[1]

# Remove the last 7 columns
df = df.drop(df.columns[num_columns-7:], axis=1)
df["Month"] = df["Month"].apply(lambda x: x.split("-")[1])

df.tail(-2)
# Out:
#      Month  Latitude  Longitude  Count   Salinity  Temperature   Acidity  \
# 2       12      31.0       27.0     13  38.697234    19.879898  8.094135
# 3       12      31.0       28.0     38  38.772010    20.552371  8.084135
# 4       12      31.0       29.0     48  38.836603    20.770606  8.083319
# 5       12      31.0       30.0     47  38.830344    20.359030  8.106045
# 6       12      31.0       31.0      2  39.031396    20.238005  8.115373
# ...    ...       ...        ...    ...        ...          ...       ...
# 9104    12      44.0       14.0    225  38.316125    16.414821  8.136798
# 9105    12      44.0       15.0     43  37.957863    15.387796  8.147993
# 9106    12      45.0       12.0      1  36.661519    13.043289  8.194665
# 9107    12      45.0       13.0      8  37.700932    14.229338  8.165619
# 9108    12      45.0       14.0      4  37.405774    14.448680  8.162135
#
#         Carbon  Alkalinity  Precipitation   Alk/Sal
# 2     2.351454    2.704876       0.645974  0.069898
# 3     2.350173    2.704298       0.582848  0.069749
# 4     2.348381    2.704870       0.903497  0.069647
# 5     2.359948    2.730872       0.778082  0.070328
# 6     2.373190    2.753195       0.783134  0.070538
# ...        ...         ...            ...       ...
# 9104  2.378079    2.723378       3.917398  0.071077
# 9105  2.374119    2.712510       2.860228  0.071461
# 9106  2.459669    2.803127       4.762816  0.076460
# 9107  2.329798    2.661838       5.975506  0.070604
# 9108  2.353988    2.685463       2.695858  0.071793
#
# [9107 rows x 11 columns]

# %%
import numpy as np
df["Count"] = np.log(df["Count"])
df.tail(-2)
# Out:
#      Month  Latitude  Longitude     Count   Salinity  Temperature   Acidity  \
# 2       12      31.0       27.0  2.564949  38.697234    19.879898  8.094135
# 3       12      31.0       28.0  3.637586  38.772010    20.552371  8.084135
# 4       12      31.0       29.0  3.871201  38.836603    20.770606  8.083319
# 5       12      31.0       30.0  3.850148  38.830344    20.359030  8.106045
# 6       12      31.0       31.0  0.693147  39.031396    20.238005  8.115373
# ...    ...       ...        ...       ...        ...          ...       ...
# 9104    12      44.0       14.0  5.416100  38.316125    16.414821  8.136798
# 9105    12      44.0       15.0  3.761200  37.957863    15.387796  8.147993
# 9106    12      45.0       12.0  0.000000  36.661519    13.043289  8.194665
# 9107    12      45.0       13.0  2.079442  37.700932    14.229338  8.165619
# 9108    12      45.0       14.0  1.386294  37.405774    14.448680  8.162135
#
#         Carbon  Alkalinity  Precipitation   Alk/Sal
# 2     2.351454    2.704876       0.645974  0.069898
# 3     2.350173    2.704298       0.582848  0.069749
# 4     2.348381    2.704870       0.903497  0.069647
# 5     2.359948    2.730872       0.778082  0.070328
# 6     2.373190    2.753195       0.783134  0.070538
# ...        ...         ...            ...       ...
# 9104  2.378079    2.723378       3.917398  0.071077
# 9105  2.374119    2.712510       2.860228  0.071461
# 9106  2.459669    2.803127       4.762816  0.076460
# 9107  2.329798    2.661838       5.975506  0.070604
# 9108  2.353988    2.685463       2.695858  0.071793
#
# [9107 rows x 11 columns]

# %%
import pandas as pd

df = pd.read_csv('../relevant csvs/Frequency for correlation2.csv')
df = df.dropna()
num_columns = df.shape[1]

# Remove the last 7 columns
#df = df.drop(df.columns[num_columns-7:], axis=1)
df = df[~df['Month'].str.startswith('2020')]
df = df.groupby(['Month','Latitude', 'Longitude','Power (J)count','Power (J)mean', 'Sodium','Temperature','pH','Carbon','Alkalinity'], as_index=False).agg({'Precipitation': "sum"})

df["Month"] = df["Month"].apply(lambda x: x.split("-")[1])
df = df[df['Power (J)count']>0]
df
# Out:
#       Month  Latitude  Longitude  Power (J)count  Power (J)mean     Sodium  \
# 8        12      31.0       17.0             1.0    1747.330000  38.352597
# 14       12      31.0       26.0             1.0   21586.630000  38.601412
# 15       12      31.0       27.0            13.0   10764.926154  38.697234
# 16       12      31.0       28.0            38.0   10836.028684  38.772010
# 17       12      31.0       29.0            48.0   12794.811667  38.836603
# ...     ...       ...        ...             ...            ...        ...
# 10504    12      44.0       14.0           225.0     721.654533  38.316125
# 10505    12      44.0       15.0            43.0     680.203721  37.957863
# 10506    12      45.0       12.0             1.0      47.270000  36.661519
# 10507    12      45.0       13.0             8.0      71.916250  37.700932
# 10508    12      45.0       14.0             4.0     352.550000  37.405774
#
#        Temperature        pH    Carbon  Alkalinity  Precipitation
# 8        20.059435  8.094838  2.342358    2.694373      20.079572
# 14       19.575738  8.098050  2.350928    2.702863      20.579652
# 15       19.879898  8.094135  2.351454    2.704876      20.025204
# 16       20.552371  8.084135  2.350173    2.704298      18.068275
# 17       20.770606  8.083319  2.348381    2.704870      28.008409
# ...            ...       ...       ...         ...            ...
# 10504    16.414821  8.136798  2.378079    2.723378     121.439349
# 10505    15.387796  8.147993  2.374119    2.712510      88.667070
# 10506    13.043289  8.194665  2.459669    2.803127     147.647299
# 10507    14.229338  8.165619  2.329798    2.661838     185.240701
# 10508    14.448680  8.162135  2.353988    2.685463      83.571606
#
# [9109 rows x 11 columns]

# %%
#month to dummy vars

dummy_variables = pd.get_dummies(df['Month'], prefix='Month')

df = pd.concat([df, dummy_variables], axis=1)

df["alk/sal"] = df["Alkalinity"] / df["Sodium"]

df
# Out:
#       Month  Latitude  Longitude  Power (J)count  Power (J)mean     Sodium  \
# 8        12      31.0       17.0             1.0    1747.330000  38.352597
# 14       12      31.0       26.0             1.0   21586.630000  38.601412
# 15       12      31.0       27.0            13.0   10764.926154  38.697234
# 16       12      31.0       28.0            38.0   10836.028684  38.772010
# 17       12      31.0       29.0            48.0   12794.811667  38.836603
# ...     ...       ...        ...             ...            ...        ...
# 10504    12      44.0       14.0           225.0     721.654533  38.316125
# 10505    12      44.0       15.0            43.0     680.203721  37.957863
# 10506    12      45.0       12.0             1.0      47.270000  36.661519
# 10507    12      45.0       13.0             8.0      71.916250  37.700932
# 10508    12      45.0       14.0             4.0     352.550000  37.405774
#
#        Temperature        pH    Carbon  Alkalinity  Precipitation  Month_01  \
# 8        20.059435  8.094838  2.342358    2.694373      20.079572         0
# 14       19.575738  8.098050  2.350928    2.702863      20.579652         0
# 15       19.879898  8.094135  2.351454    2.704876      20.025204         0
# 16       20.552371  8.084135  2.350173    2.704298      18.068275         0
# 17       20.770606  8.083319  2.348381    2.704870      28.008409         0
# ...            ...       ...       ...         ...            ...       ...
# 10504    16.414821  8.136798  2.378079    2.723378     121.439349         0
# 10505    15.387796  8.147993  2.374119    2.712510      88.667070         0
# 10506    13.043289  8.194665  2.459669    2.803127     147.647299         0
# 10507    14.229338  8.165619  2.329798    2.661838     185.240701         0
# 10508    14.448680  8.162135  2.353988    2.685463      83.571606         0
#
#        Month_02  Month_12   alk/sal
# 8             0         1  0.070253
# 14            0         1  0.070020
# 15            0         1  0.069898
# 16            0         1  0.069749
# 17            0         1  0.069647
# ...         ...       ...       ...
# 10504         0         1  0.071077
# 10505         0         1  0.071461
# 10506         0         1  0.076460
# 10507         0         1  0.070604
# 10508         0         1  0.071793
#
# [9109 rows x 15 columns]

# %%
#LinearRegression code for building a model with specific features
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.feature_selection import SelectKBest, f_regression

max_accuracy = 0
best_features = []

# Load the data into a Pandas dataframe
df = pd.read_csv("../RELEVANT CSVS/frequency for correlation.csv")


# Define the target variable and the features you want to use for prediction
target = 'Count'
features = ['Latitude', 'Longitude', 'Acidity', 'Alkalinity', 'Carbon', 'Precipitation']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df[features], np.log(df[target]), test_size=0.3, random_state=42)

# Use SelectKBest to select the top k features based on f_regression score
selector = SelectKBest(f_regression, k=6)
X_train = selector.fit_transform(X_train, y_train)
X_test = selector.transform(X_test)

# Create a linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model's performance using R-squared metric
r2 = r2_score(y_test, y_pred)

print(r2)

# %%
#LinearRegression code that tries all possible combinations of features and prints the best combination

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from itertools import combinations

# Define the target variable and the features you want to use for prediction
target = 'Power (J)mean'
all_features = ['Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation','Month_01','Month_02','Month_12','alk/sal']

max_r2 = 0
best_features = []
rmse_train2 = 0


# Generate all possible combinations of features
for r in range(1, len(all_features) + 1):
    feature_combinations = combinations(all_features, r)
    for features in feature_combinations:
        # Split the data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(df[list(features)], np.log(df[target]), test_size=0.3, random_state=42)

        # Create a linear regression model
        model = LinearRegression()

        # Fit the model to the training data
        model.fit(X_train, y_train)

        # Make predictions on the test data
        y_pred = model.predict(X_test)

        # Evaluate the model's performance using R-squared metric
        r2 = r2_score(y_test, y_pred)
        rmse_test = np.sqrt(mean_squared_error(np.exp(y_test), np.exp(y_pred)))
        y_pred_train = model.predict(X_train)
        rmse_train = np.sqrt(mean_squared_error(np.exp(y_train), np.exp(y_pred_train)))

        # Update the best features and max R-squared score if necessary
        if r2 > max_r2:
            max_r2 = r2
            best_features_r2 = features
            rmse2= rmse_test
            rmse_train1 = rmse_train

# Print the best features and the corresponding R-squared score
print("Best Features for max r2:", best_features_r2)
print("R-squared Score:", max_r2)
print("RMSE on test set: {:.6f}".format(rmse2))
print("RMSE on train set: {:.6f}".format(rmse_train))
# Out:
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.06964258619157737
# RMSE on test set: 43120.431370
# RMSE on train set: 52832.004116

# %%
#DecisionTree code for building a model with specific features

from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from itertools import combinations

# Define the target variable and the features you want to use for prediction
target = 'Count'
all_features = ['Latitude', 'Longitude', 'Acidity', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12']

max_r2 = 0
best_features = []

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df[list(all_features)], np.log(df[target]), test_size=0.3, random_state=42)


# Create a decision tree regression model
model = DecisionTreeRegressor(max_depth=8)

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model's performance using R-squared metric
r2 = r2_score(y_test, y_pred)
rmse_test = np.sqrt(mean_squared_error(np.exp(y_test), np.exp(y_pred)))
y_pred_train = model.predict(X_train)
rmse_train = np.sqrt(mean_squared_error(np.exp(y_train), np.exp(y_pred_train)))

if r2 > max_r2:
    max_r2 = r2
    best_features = features
    best_rmse= rmse_test
    best_rmse_train = rmse_train

print("Best Features for max r2:", best_features)
print("R-squared Score:", max_r2)
print("RMSE on test set: {:.6f}".format(best_rmse))
print("RMSE on train set: {:.6f}".format(best_rmse_train))
print("----------------------------------------------")

# %%
#LinearRegression code that tries all possible combinations of features and prints the best combination as well as all combinations with r2<0.346

from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from itertools import combinations

# Define the target variable and the features you want to use for prediction
target = 'Power (J)mean'
all_features = ['Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation','Month_01','Month_02','Month_12','alk/sal']

max_r2 = 0
best_features = []

# Generate all possible combinations of features
for r in range(1, len(all_features) + 1):
    feature_combinations = combinations(all_features, r)
    for features in feature_combinations:
        # Split the data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(df[list(features)], np.log(df[target]), test_size=0.3, random_state=42)

        
        # Create a decision tree regression model
        model = DecisionTreeRegressor(max_depth=r)

        # Fit the model to the training data
        model.fit(X_train, y_train)

        # Make predictions on the test data
        y_pred = model.predict(X_test)

        # Evaluate the model's performance using R-squared metric
        r2 = r2_score(y_test, y_pred)
        rmse_test = np.sqrt(mean_squared_error(np.exp(y_test), np.exp(y_pred)))
        y_pred_train = model.predict(X_train)
        rmse_train = np.sqrt(mean_squared_error(np.exp(y_train), np.exp(y_pred_train)))

        if(r2>0.001):
            print("Best Features for max r2:", features)
            print("R-squared Score:", r2)
            print("RMSE on test set: {:.6f}".format(rmse_test))
            print("RMSE on train set: {:.6f}".format(rmse_train))
            print("+++++++++++++++++++++++++++++++++++++++++++++++")

        if r2 > max_r2:
            max_r2 = r2
            best_features = features
            best_rmse= rmse_test
            best_rmse_train = rmse_train

print("Best Features for max r2:", best_features)
print("R-squared Score:", max_r2)
print("RMSE on test set: {:.6f}".format(best_rmse))
print("RMSE on train set: {:.6f}".format(best_rmse_train))
print("----------------------------------------------")
# Out:
# Best Features for max r2: ('Latitude',)
# R-squared Score: 0.0017790658774772261
# RMSE on test set: 43805.754853
# RMSE on train set: 53360.201544
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude',)
# R-squared Score: 0.0019236436380178912
# RMSE on test set: 43702.250070
# RMSE on train set: 53224.765143
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium',)
# R-squared Score: 0.010611859666507906
# RMSE on test set: 43649.513246
# RMSE on train set: 53209.734504
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature',)
# R-squared Score: 0.004759261719730179
# RMSE on test set: 43645.966361
# RMSE on train set: 53212.457973
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH',)
# R-squared Score: 0.005678468967324157
# RMSE on test set: 43688.103380
# RMSE on train set: 53235.105815
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Alkalinity',)
# R-squared Score: 0.017476111536632866
# RMSE on test set: 43614.549945
# RMSE on train set: 53162.341033
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Carbon',)
# R-squared Score: 0.027374672244015352
# RMSE on test set: 43566.274511
# RMSE on train set: 53152.089532
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Month_01',)
# R-squared Score: 0.012609930832597094
# RMSE on test set: 43624.446433
# RMSE on train set: 53238.999698
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Month_12',)
# R-squared Score: 0.02772132825787088
# RMSE on test set: 43457.512628
# RMSE on train set: 53106.388275
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('alk/sal',)
# R-squared Score: 0.018866712845035494
# RMSE on test set: 43696.865433
# RMSE on train set: 53244.546122
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude')
# R-squared Score: 0.022864188334606905
# RMSE on test set: 43612.453647
# RMSE on train set: 53156.169286
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium')
# R-squared Score: 0.016516878914126454
# RMSE on test set: 43597.078247
# RMSE on train set: 53177.502304
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH')
# R-squared Score: 0.012575813744814424
# RMSE on test set: 43672.525351
# RMSE on train set: 53216.011958
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Alkalinity')
# R-squared Score: 0.02793943987289127
# RMSE on test set: 43545.441470
# RMSE on train set: 53124.705741
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Carbon')
# R-squared Score: 0.03593252419938142
# RMSE on test set: 43501.727741
# RMSE on train set: 53111.097895
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Month_01')
# R-squared Score: 0.013401977440372748
# RMSE on test set: 43586.172456
# RMSE on train set: 53212.147489
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Month_12')
# R-squared Score: 0.02509839906613265
# RMSE on test set: 43399.608696
# RMSE on train set: 53003.241842
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'alk/sal')
# R-squared Score: 0.015127072071552394
# RMSE on test set: 43511.281435
# RMSE on train set: 53045.646360
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium')
# R-squared Score: 0.016074416338279995
# RMSE on test set: 43545.557718
# RMSE on train set: 53095.315208
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH')
# R-squared Score: 0.008353510865703795
# RMSE on test set: 43520.124040
# RMSE on train set: 53048.993018
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Alkalinity')
# R-squared Score: 0.027085110409124757
# RMSE on test set: 43512.121606
# RMSE on train set: 53085.780594
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Carbon')
# R-squared Score: 0.031088617105057392
# RMSE on test set: 43499.392442
# RMSE on train set: 53069.346647
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Precipitation')
# R-squared Score: 0.005327326320983872
# RMSE on test set: 43595.832261
# RMSE on train set: 53068.915844
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_01')
# R-squared Score: 0.01640357364270273
# RMSE on test set: 43494.329218
# RMSE on train set: 53086.400983
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_02')
# R-squared Score: 0.007061104775753391
# RMSE on test set: 43635.525108
# RMSE on train set: 53167.581930
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_12')
# R-squared Score: 0.03088005034813701
# RMSE on test set: 43274.905940
# RMSE on train set: 52928.001875
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'alk/sal')
# R-squared Score: 0.026894370417431812
# RMSE on test set: 43597.065579
# RMSE on train set: 53149.331705
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature')
# R-squared Score: 0.015686581759900342
# RMSE on test set: 43521.576708
# RMSE on train set: 53091.556889
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH')
# R-squared Score: 0.0161427586208458
# RMSE on test set: 43525.094891
# RMSE on train set: 53093.133664
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Alkalinity')
# R-squared Score: 0.026871731756075046
# RMSE on test set: 43508.386087
# RMSE on train set: 53074.141933
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Carbon')
# R-squared Score: 0.03515571356311309
# RMSE on test set: 43455.614676
# RMSE on train set: 53033.729730
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Precipitation')
# R-squared Score: 0.015264874044591203
# RMSE on test set: 43576.949278
# RMSE on train set: 53121.144599
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_01')
# R-squared Score: 0.022991929463178185
# RMSE on test set: 43432.197230
# RMSE on train set: 53065.627126
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_02')
# R-squared Score: 0.014816628835242485
# RMSE on test set: 43655.724642
# RMSE on train set: 53201.701979
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_12')
# R-squared Score: 0.03897422465729927
# RMSE on test set: 43254.302199
# RMSE on train set: 52922.703809
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'alk/sal')
# R-squared Score: 0.03348887435093195
# RMSE on test set: 43465.435125
# RMSE on train set: 53010.888404
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH')
# R-squared Score: 0.0030134563857424634
# RMSE on test set: 43606.498205
# RMSE on train set: 53072.200413
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Alkalinity')
# R-squared Score: 0.027775847195424475
# RMSE on test set: 43446.238812
# RMSE on train set: 53014.718022
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Carbon')
# R-squared Score: 0.03818093959175983
# RMSE on test set: 43346.617594
# RMSE on train set: 52949.180901
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Precipitation')
# R-squared Score: 0.0065174065220244826
# RMSE on test set: 43593.952523
# RMSE on train set: 53142.387248
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Month_01')
# R-squared Score: 0.024392582668676388
# RMSE on test set: 43330.015506
# RMSE on train set: 52974.175568
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Month_12')
# R-squared Score: 0.022424350870107412
# RMSE on test set: 43434.963380
# RMSE on train set: 53080.064636
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'alk/sal')
# R-squared Score: 0.018642948172168605
# RMSE on test set: 43346.092957
# RMSE on train set: 52927.365790
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH', 'Alkalinity')
# R-squared Score: 0.027892357816847846
# RMSE on test set: 43450.615453
# RMSE on train set: 53022.280017
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH', 'Carbon')
# R-squared Score: 0.04268517582115994
# RMSE on test set: 43348.262540
# RMSE on train set: 52952.983160
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH', 'Precipitation')
# R-squared Score: 0.00788578988252342
# RMSE on test set: 43629.821840
# RMSE on train set: 53164.356295
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH', 'Month_01')
# R-squared Score: 0.020698110187858942
# RMSE on test set: 43438.729851
# RMSE on train set: 53108.048587
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH', 'Month_02')
# R-squared Score: 0.014662139915420092
# RMSE on test set: 43669.959419
# RMSE on train set: 53215.136648
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH', 'Month_12')
# R-squared Score: 0.029873708056304737
# RMSE on test set: 43397.554068
# RMSE on train set: 53017.045008
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH', 'alk/sal')
# R-squared Score: 0.030211261610128215
# RMSE on test set: 43486.029136
# RMSE on train set: 53046.572076
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Alkalinity', 'Carbon')
# R-squared Score: 0.0318995978831883
# RMSE on test set: 43507.939289
# RMSE on train set: 53082.675353
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Alkalinity', 'Precipitation')
# R-squared Score: 0.02489757864496156
# RMSE on test set: 43516.553067
# RMSE on train set: 53062.291084
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Alkalinity', 'Month_01')
# R-squared Score: 0.033339890680122775
# RMSE on test set: 43396.226072
# RMSE on train set: 53032.805906
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Alkalinity', 'Month_02')
# R-squared Score: 0.027085110409124202
# RMSE on test set: 43512.121606
# RMSE on train set: 53085.780594
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Alkalinity', 'Month_12')
# R-squared Score: 0.04330889625426537
# RMSE on test set: 43211.138151
# RMSE on train set: 52864.031594
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Alkalinity', 'alk/sal')
# R-squared Score: 0.0337378462198511
# RMSE on test set: 43531.527763
# RMSE on train set: 53100.911749
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Carbon', 'Precipitation')
# R-squared Score: 0.034079006509821874
# RMSE on test set: 43497.346856
# RMSE on train set: 53055.618840
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Carbon', 'Month_01')
# R-squared Score: 0.04041494594279538
# RMSE on test set: 43338.053213
# RMSE on train set: 53005.896865
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Carbon', 'Month_02')
# R-squared Score: 0.031356449264064445
# RMSE on test set: 43539.653687
# RMSE on train set: 53110.904744
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Carbon', 'Month_12')
# R-squared Score: 0.05349445462587732
# RMSE on test set: 43132.833922
# RMSE on train set: 52824.113960
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Carbon', 'alk/sal')
# R-squared Score: 0.03968379155288926
# RMSE on test set: 43487.142591
# RMSE on train set: 53074.265607
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Precipitation', 'Month_01')
# R-squared Score: 0.014776271404415064
# RMSE on test set: 43581.449496
# RMSE on train set: 53175.726547
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Precipitation', 'Month_02')
# R-squared Score: 0.0035108893226964977
# RMSE on test set: 43713.877375
# RMSE on train set: 53222.131814
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Precipitation', 'Month_12')
# R-squared Score: 0.029188242628965688
# RMSE on test set: 43387.685035
# RMSE on train set: 53021.446956
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Precipitation', 'alk/sal')
# R-squared Score: 0.021108046561178595
# RMSE on test set: 43623.458037
# RMSE on train set: 53139.414505
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Month_01', 'Month_02')
# R-squared Score: 0.02845130045734634
# RMSE on test set: 43432.524815
# RMSE on train set: 53096.740349
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Month_01', 'Month_12')
# R-squared Score: 0.028451300457346118
# RMSE on test set: 43432.524815
# RMSE on train set: 53096.740349
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Month_01', 'alk/sal')
# R-squared Score: 0.032777853264725376
# RMSE on test set: 43473.470101
# RMSE on train set: 53092.617335
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Month_02', 'Month_12')
# R-squared Score: 0.028451300457346673
# RMSE on test set: 43432.524815
# RMSE on train set: 53096.740349
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Month_02', 'alk/sal')
# R-squared Score: 0.026894370417432034
# RMSE on test set: 43597.065579
# RMSE on train set: 53149.331705
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Month_12', 'alk/sal')
# R-squared Score: 0.045523316834615524
# RMSE on test set: 43303.032111
# RMSE on train set: 52958.300493
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium')
# R-squared Score: 0.022752411986367016
# RMSE on test set: 43470.736792
# RMSE on train set: 53004.248279
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature')
# R-squared Score: 0.001670659918041828
# RMSE on test set: 43500.991927
# RMSE on train set: 53050.823066
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'pH')
# R-squared Score: 0.0293060806565425
# RMSE on test set: 43396.564638
# RMSE on train set: 52929.622341
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Alkalinity')
# R-squared Score: 0.030107870751394317
# RMSE on test set: 43482.657498
# RMSE on train set: 53043.824320
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Carbon')
# R-squared Score: 0.03039659271403794
# RMSE on test set: 43450.262954
# RMSE on train set: 53036.166843
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Precipitation')
# R-squared Score: 0.013203388862819465
# RMSE on test set: 43586.870716
# RMSE on train set: 53004.973509
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Month_01')
# R-squared Score: 0.023085507825653218
# RMSE on test set: 43348.489906
# RMSE on train set: 52986.098618
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Month_02')
# R-squared Score: 0.032549436272332866
# RMSE on test set: 43567.332724
# RMSE on train set: 53102.720715
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Month_12')
# R-squared Score: 0.05212717750445839
# RMSE on test set: 43168.062330
# RMSE on train set: 52845.226266
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'alk/sal')
# R-squared Score: 0.022739244920627844
# RMSE on test set: 43465.366947
# RMSE on train set: 52934.563177
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature')
# R-squared Score: 0.010847599276527009
# RMSE on test set: 43509.586744
# RMSE on train set: 53064.999728
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH')
# R-squared Score: 0.017327768150326772
# RMSE on test set: 43520.448166
# RMSE on train set: 53033.662343
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Alkalinity')
# R-squared Score: 0.03496346986862853
# RMSE on test set: 43423.354742
# RMSE on train set: 53014.197453
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Carbon')
# R-squared Score: 0.029204549526679946
# RMSE on test set: 43473.777298
# RMSE on train set: 53035.095039
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Precipitation')
# R-squared Score: 0.013368169683632303
# RMSE on test set: 43503.685769
# RMSE on train set: 53019.290633
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Month_01')
# R-squared Score: 0.022290869553294623
# RMSE on test set: 43429.439372
# RMSE on train set: 53039.564139
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Month_02')
# R-squared Score: 0.013637860661756318
# RMSE on test set: 43607.038315
# RMSE on train set: 53147.863321
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Month_12')
# R-squared Score: 0.04745061694607955
# RMSE on test set: 43215.961002
# RMSE on train set: 52886.227368
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'alk/sal')
# R-squared Score: 0.026889661987898772
# RMSE on test set: 43392.997282
# RMSE on train set: 52829.577588
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'pH')
# R-squared Score: 0.009430902442537414
# RMSE on test set: 43663.724483
# RMSE on train set: 52999.606718
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'Alkalinity')
# R-squared Score: 0.024294794774381012
# RMSE on test set: 43265.734070
# RMSE on train set: 52847.439606
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'Carbon')
# R-squared Score: 0.03382033284739305
# RMSE on test set: 43172.900320
# RMSE on train set: 52766.542076
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'Precipitation')
# R-squared Score: 0.002381614554348155
# RMSE on test set: 43529.131069
# RMSE on train set: 53055.305998
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'Month_01')
# R-squared Score: 0.02059798340689112
# RMSE on test set: 43251.213410
# RMSE on train set: 52894.773155
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'Month_12')
# R-squared Score: 0.020834523623414647
# RMSE on test set: 43395.275145
# RMSE on train set: 53041.657506
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'alk/sal')
# R-squared Score: 0.024394406071826413
# RMSE on test set: 43205.216695
# RMSE on train set: 52634.713725
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH', 'Alkalinity')
# R-squared Score: 0.030977267453605073
# RMSE on test set: 43320.892789
# RMSE on train set: 52902.670821
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH', 'Carbon')
# R-squared Score: 0.053902355390968104
# RMSE on test set: 43229.493891
# RMSE on train set: 52854.160634
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH', 'Precipitation')
# R-squared Score: 0.013757220649033064
# RMSE on test set: 43543.594573
# RMSE on train set: 53054.534838
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH', 'Month_01')
# R-squared Score: 0.017392598402627635
# RMSE on test set: 43391.735443
# RMSE on train set: 53010.094211
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH', 'Month_02')
# R-squared Score: 0.012026220025393108
# RMSE on test set: 43625.073191
# RMSE on train set: 53134.426915
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH', 'Month_12')
# R-squared Score: 0.03772697224846633
# RMSE on test set: 43156.947545
# RMSE on train set: 52736.609221
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH', 'alk/sal')
# R-squared Score: 0.029961643003942995
# RMSE on test set: 43325.241554
# RMSE on train set: 52770.623573
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Alkalinity', 'Carbon')
# R-squared Score: 0.033607514882775025
# RMSE on test set: 43456.043081
# RMSE on train set: 53005.519625
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Alkalinity', 'Precipitation')
# R-squared Score: 0.027209674980940735
# RMSE on test set: 43508.755052
# RMSE on train set: 52850.159184
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Alkalinity', 'Month_01')
# R-squared Score: 0.033690924026433144
# RMSE on test set: 43476.617930
# RMSE on train set: 52918.418894
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Alkalinity', 'Month_02')
# R-squared Score: 0.0277647757293098
# RMSE on test set: 43613.444060
# RMSE on train set: 52995.370457
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Alkalinity', 'Month_12')
# R-squared Score: 0.04812727887214652
# RMSE on test set: 43073.878019
# RMSE on train set: 52749.834130
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Alkalinity', 'alk/sal')
# R-squared Score: 0.02494470461240872
# RMSE on test set: 43387.759459
# RMSE on train set: 52926.119569
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Carbon', 'Precipitation')
# R-squared Score: 0.02590300250028066
# RMSE on test set: 43429.062648
# RMSE on train set: 52907.941833
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Carbon', 'Month_01')
# R-squared Score: 0.04288360353052001
# RMSE on test set: 43305.623749
# RMSE on train set: 52948.843129
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Carbon', 'Month_02')
# R-squared Score: 0.02663453048263531
# RMSE on test set: 43463.225191
# RMSE on train set: 53028.243301
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Carbon', 'Month_12')
# R-squared Score: 0.05931900534471335
# RMSE on test set: 42993.572518
# RMSE on train set: 52688.413546
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Carbon', 'alk/sal')
# R-squared Score: 0.0296774946860191
# RMSE on test set: 43348.095555
# RMSE on train set: 52871.628505
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Precipitation', 'Month_01')
# R-squared Score: 0.01618045251096567
# RMSE on test set: 43458.914246
# RMSE on train set: 53015.454026
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Precipitation', 'Month_02')
# R-squared Score: 0.008664254452502629
# RMSE on test set: 43670.103579
# RMSE on train set: 53187.738820
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Precipitation', 'Month_12')
# R-squared Score: 0.034555816183741705
# RMSE on test set: 43270.288941
# RMSE on train set: 52936.760654
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Precipitation', 'alk/sal')
# R-squared Score: 0.021601907043305335
# RMSE on test set: 43369.819385
# RMSE on train set: 52849.758343
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Month_01', 'Month_02')
# R-squared Score: 0.026592824251100322
# RMSE on test set: 43399.028485
# RMSE on train set: 53031.261435
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Month_01', 'Month_12')
# R-squared Score: 0.030310643440457752
# RMSE on test set: 43392.016332
# RMSE on train set: 53058.310377
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Month_01', 'alk/sal')
# R-squared Score: 0.02672396579518077
# RMSE on test set: 43398.450406
# RMSE on train set: 52952.548997
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Month_02', 'Month_12')
# R-squared Score: 0.030310643440457752
# RMSE on test set: 43392.016332
# RMSE on train set: 53058.310377
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Month_02', 'alk/sal')
# R-squared Score: 0.024088103468012267
# RMSE on test set: 43377.677699
# RMSE on train set: 52883.489058
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Month_12', 'alk/sal')
# R-squared Score: 0.0555972526701054
# RMSE on test set: 43080.544728
# RMSE on train set: 52794.384690
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature')
# R-squared Score: 0.012038389131378113
# RMSE on test set: 43512.813354
# RMSE on train set: 53064.921098
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH')
# R-squared Score: 0.022178760710737655
# RMSE on test set: 43516.874963
# RMSE on train set: 53043.299889
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Alkalinity')
# R-squared Score: 0.03521875893638193
# RMSE on test set: 43502.014682
# RMSE on train set: 53075.804385
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Carbon')
# R-squared Score: 0.03112617652275962
# RMSE on test set: 43470.459482
# RMSE on train set: 53039.412886
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Precipitation')
# R-squared Score: 0.022296741731955505
# RMSE on test set: 43493.859466
# RMSE on train set: 53050.421189
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Month_01')
# R-squared Score: 0.0281645101455118
# RMSE on test set: 43407.660907
# RMSE on train set: 52989.439602
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Month_02')
# R-squared Score: 0.02130691749418656
# RMSE on test set: 43527.101514
# RMSE on train set: 53039.391626
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Month_12')
# R-squared Score: 0.042698871770364244
# RMSE on test set: 43128.322991
# RMSE on train set: 52796.436436
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'alk/sal')
# R-squared Score: 0.039973883353546236
# RMSE on test set: 43462.976261
# RMSE on train set: 52982.526154
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'pH')
# R-squared Score: 0.006341153604796923
# RMSE on test set: 43449.971285
# RMSE on train set: 52876.333239
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Alkalinity')
# R-squared Score: 0.031617013140618155
# RMSE on test set: 43271.642108
# RMSE on train set: 52849.156087
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Carbon')
# R-squared Score: 0.03622933320771149
# RMSE on test set: 43165.203466
# RMSE on train set: 52763.800868
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Precipitation')
# R-squared Score: 0.0025381741995254004
# RMSE on test set: 43528.700740
# RMSE on train set: 53055.151979
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Month_01')
# R-squared Score: 0.020469230669134975
# RMSE on test set: 43250.909519
# RMSE on train set: 52894.463512
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Month_02')
# R-squared Score: 0.0016706599180429382
# RMSE on test set: 43500.991927
# RMSE on train set: 53050.823066
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Month_12')
# R-squared Score: 0.026594981848811483
# RMSE on test set: 43249.145687
# RMSE on train set: 52890.338688
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'alk/sal')
# R-squared Score: 0.021681651952432546
# RMSE on test set: 43292.211497
# RMSE on train set: 52797.079378
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Alkalinity')
# R-squared Score: 0.0300114769068891
# RMSE on test set: 43321.711618
# RMSE on train set: 52894.788191
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Carbon')
# R-squared Score: 0.05120426982902415
# RMSE on test set: 43226.882491
# RMSE on train set: 52834.929222
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Precipitation')
# R-squared Score: 0.01887952624724676
# RMSE on test set: 43404.942174
# RMSE on train set: 52921.708346
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Month_01')
# R-squared Score: 0.020046085126834035
# RMSE on test set: 43337.287485
# RMSE on train set: 52919.832271
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Month_02')
# R-squared Score: 0.01710599801356405
# RMSE on test set: 43410.903910
# RMSE on train set: 52925.744190
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Month_12')
# R-squared Score: 0.037035594601946276
# RMSE on test set: 43166.486873
# RMSE on train set: 52776.486575
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'alk/sal')
# R-squared Score: 0.03734743358674697
# RMSE on test set: 43356.219197
# RMSE on train set: 52887.832867
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Alkalinity', 'Carbon')
# R-squared Score: 0.031043643534203413
# RMSE on test set: 43544.666608
# RMSE on train set: 53092.820082
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Alkalinity', 'Precipitation')
# R-squared Score: 0.026124670519991122
# RMSE on test set: 43381.482492
# RMSE on train set: 52896.519416
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Alkalinity', 'Month_01')
# R-squared Score: 0.03882587992556363
# RMSE on test set: 43404.586536
# RMSE on train set: 52969.483677
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Alkalinity', 'Month_02')
# R-squared Score: 0.03447120974827922
# RMSE on test set: 43528.356056
# RMSE on train set: 53058.784693
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Alkalinity', 'Month_12')
# R-squared Score: 0.0554552903095078
# RMSE on test set: 43095.932287
# RMSE on train set: 52786.733439
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Alkalinity', 'alk/sal')
# R-squared Score: 0.03640207807567786
# RMSE on test set: 43480.056814
# RMSE on train set: 53036.007542
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Carbon', 'Precipitation')
# R-squared Score: 0.028326044756200264
# RMSE on test set: 43422.828546
# RMSE on train set: 52911.141099
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Carbon', 'Month_01')
# R-squared Score: 0.04092158903613097
# RMSE on test set: 43372.933338
# RMSE on train set: 52991.105186
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Carbon', 'Month_02')
# R-squared Score: 0.033569006505124066
# RMSE on test set: 43453.734435
# RMSE on train set: 53003.061828
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Carbon', 'Month_12')
# R-squared Score: 0.06213870750880446
# RMSE on test set: 43057.953140
# RMSE on train set: 52744.139561
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Carbon', 'alk/sal')
# R-squared Score: 0.03313321640259925
# RMSE on test set: 43477.622100
# RMSE on train set: 53036.594215
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Precipitation', 'Month_01')
# R-squared Score: 0.020475705516291853
# RMSE on test set: 43410.927103
# RMSE on train set: 52987.926935
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Precipitation', 'Month_02')
# R-squared Score: 0.014034874195496094
# RMSE on test set: 43467.952718
# RMSE on train set: 52942.037272
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Precipitation', 'Month_12')
# R-squared Score: 0.034776322679638594
# RMSE on test set: 43132.807674
# RMSE on train set: 52755.748575
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Precipitation', 'alk/sal')
# R-squared Score: 0.030792923388307636
# RMSE on test set: 43405.419920
# RMSE on train set: 52960.753551
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_01', 'Month_02')
# R-squared Score: 0.033476164273425146
# RMSE on test set: 43261.895820
# RMSE on train set: 52908.985073
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_01', 'Month_12')
# R-squared Score: 0.03529372270978037
# RMSE on test set: 43225.485989
# RMSE on train set: 52880.680044
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_01', 'alk/sal')
# R-squared Score: 0.03619180487069251
# RMSE on test set: 43428.303141
# RMSE on train set: 53006.790824
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_02', 'Month_12')
# R-squared Score: 0.03529372270978082
# RMSE on test set: 43225.485989
# RMSE on train set: 52880.680044
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_02', 'alk/sal')
# R-squared Score: 0.030498290936654904
# RMSE on test set: 43598.373128
# RMSE on train set: 53071.449219
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Month_12', 'alk/sal')
# R-squared Score: 0.05205201383980673
# RMSE on test set: 43179.266104
# RMSE on train set: 52829.910641
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH')
# R-squared Score: 0.016082606886705264
# RMSE on test set: 43536.554910
# RMSE on train set: 52967.686691
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Alkalinity')
# R-squared Score: 0.028982235362108533
# RMSE on test set: 43242.128820
# RMSE on train set: 52839.825126
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Carbon')
# R-squared Score: 0.03401470696725695
# RMSE on test set: 43158.410396
# RMSE on train set: 52765.420470
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Precipitation')
# R-squared Score: 0.014041164172319931
# RMSE on test set: 43424.428513
# RMSE on train set: 52947.755317
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Month_01')
# R-squared Score: 0.023803780768737792
# RMSE on test set: 43176.997671
# RMSE on train set: 52841.110409
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Month_02')
# R-squared Score: 0.011745523863176732
# RMSE on test set: 43510.137894
# RMSE on train set: 53070.115319
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Month_12')
# R-squared Score: 0.033376100774390904
# RMSE on test set: 43256.614763
# RMSE on train set: 52907.629849
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'alk/sal')
# R-squared Score: 0.02726435398421012
# RMSE on test set: 43278.823526
# RMSE on train set: 52811.025558
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Alkalinity')
# R-squared Score: 0.034163331188602264
# RMSE on test set: 43326.589098
# RMSE on train set: 52917.372840
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Carbon')
# R-squared Score: 0.05224988195186864
# RMSE on test set: 43215.525806
# RMSE on train set: 52801.810780
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Precipitation')
# R-squared Score: 0.01698834751914613
# RMSE on test set: 43453.270373
# RMSE on train set: 52999.802889
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Month_01')
# R-squared Score: 0.026577931011302014
# RMSE on test set: 43294.401006
# RMSE on train set: 52934.627437
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Month_02')
# R-squared Score: 0.022178760710736323
# RMSE on test set: 43516.874963
# RMSE on train set: 53043.299889
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Month_12')
# R-squared Score: 0.04910582183781531
# RMSE on test set: 43196.822648
# RMSE on train set: 52803.467796
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'alk/sal')
# R-squared Score: 0.04581140195804134
# RMSE on test set: 43276.934215
# RMSE on train set: 52834.495523
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Alkalinity', 'Carbon')
# R-squared Score: 0.03639113397370053
# RMSE on test set: 43483.980553
# RMSE on train set: 53044.626944
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Alkalinity', 'Precipitation')
# R-squared Score: 0.031153254723023216
# RMSE on test set: 43337.509275
# RMSE on train set: 52865.472394
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Alkalinity', 'Month_01')
# R-squared Score: 0.03985603760319678
# RMSE on test set: 43307.980769
# RMSE on train set: 52912.486781
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Alkalinity', 'Month_02')
# R-squared Score: 0.03298586356636046
# RMSE on test set: 43515.475582
# RMSE on train set: 53097.828174
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Alkalinity', 'Month_12')
# R-squared Score: 0.050346573473023515
# RMSE on test set: 43113.471844
# RMSE on train set: 52755.999075
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Alkalinity', 'alk/sal')
# R-squared Score: 0.04343950542985264
# RMSE on test set: 43381.943114
# RMSE on train set: 52953.510728
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Carbon', 'Precipitation')
# R-squared Score: 0.03055109895530661
# RMSE on test set: 43318.282464
# RMSE on train set: 52823.711606
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Carbon', 'Month_01')
# R-squared Score: 0.0464509755612883
# RMSE on test set: 43243.325542
# RMSE on train set: 52892.649236
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Carbon', 'Month_02')
# R-squared Score: 0.03112617652275962
# RMSE on test set: 43470.459482
# RMSE on train set: 53039.412886
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Carbon', 'Month_12')
# R-squared Score: 0.06307299646028164
# RMSE on test set: 43054.332604
# RMSE on train set: 52725.311736
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Carbon', 'alk/sal')
# R-squared Score: 0.035315330057987704
# RMSE on test set: 43342.816922
# RMSE on train set: 52903.062542
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Precipitation', 'Month_01')
# R-squared Score: 0.02220293384197436
# RMSE on test set: 43350.117908
# RMSE on train set: 52966.382820
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Precipitation', 'Month_02')
# R-squared Score: 0.015067944801622102
# RMSE on test set: 43502.670780
# RMSE on train set: 53020.463515
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Precipitation', 'Month_12')
# R-squared Score: 0.04485695493198716
# RMSE on test set: 43165.194077
# RMSE on train set: 52820.680626
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Precipitation', 'alk/sal')
# R-squared Score: 0.037611813824610096
# RMSE on test set: 43290.024629
# RMSE on train set: 52818.563127
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_01', 'Month_02')
# R-squared Score: 0.040091439003128615
# RMSE on test set: 43270.639337
# RMSE on train set: 52924.469937
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_01', 'Month_12')
# R-squared Score: 0.04198882712702556
# RMSE on test set: 43228.248388
# RMSE on train set: 52903.728232
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_01', 'alk/sal')
# R-squared Score: 0.0367296575526781
# RMSE on test set: 43270.136788
# RMSE on train set: 52850.099478
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_02', 'Month_12')
# R-squared Score: 0.04198882712702612
# RMSE on test set: 43228.248388
# RMSE on train set: 52903.728232
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_02', 'alk/sal')
# R-squared Score: 0.039973883353546014
# RMSE on test set: 43462.976261
# RMSE on train set: 52982.526154
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Month_12', 'alk/sal')
# R-squared Score: 0.06854254148976902
# RMSE on test set: 43039.669262
# RMSE on train set: 52712.243307
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Alkalinity')
# R-squared Score: 0.019967697662118034
# RMSE on test set: 43301.530493
# RMSE on train set: 52767.397400
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Carbon')
# R-squared Score: 0.0362878177766498
# RMSE on test set: 43265.140547
# RMSE on train set: 52809.397113
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Precipitation')
# R-squared Score: 0.013484927580199813
# RMSE on test set: 43639.082461
# RMSE on train set: 52965.232969
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Month_01')
# R-squared Score: 0.035337122807170274
# RMSE on test set: 43140.009238
# RMSE on train set: 52798.803660
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Month_02')
# R-squared Score: 0.01164680876151869
# RMSE on test set: 43555.225528
# RMSE on train set: 53001.190303
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Month_12')
# R-squared Score: 0.02832543135668464
# RMSE on test set: 43228.525929
# RMSE on train set: 52806.182188
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'alk/sal')
# R-squared Score: 0.022968514254353534
# RMSE on test set: 43277.631590
# RMSE on train set: 52786.455424
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Alkalinity', 'Carbon')
# R-squared Score: 0.0386829857737131
# RMSE on test set: 43175.746868
# RMSE on train set: 52771.396237
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Alkalinity', 'Precipitation')
# R-squared Score: 0.022472212312382944
# RMSE on test set: 43364.172573
# RMSE on train set: 52896.909519
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Alkalinity', 'Month_01')
# R-squared Score: 0.04014733551555161
# RMSE on test set: 43111.614826
# RMSE on train set: 52745.509431
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Alkalinity', 'Month_02')
# R-squared Score: 0.023761560012807492
# RMSE on test set: 43266.678494
# RMSE on train set: 52848.232807
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Alkalinity', 'Month_12')
# R-squared Score: 0.036574923552836425
# RMSE on test set: 43192.410780
# RMSE on train set: 52837.908379
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Alkalinity', 'alk/sal')
# R-squared Score: 0.03508085197167432
# RMSE on test set: 43359.839633
# RMSE on train set: 52930.103611
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Carbon', 'Precipitation')
# R-squared Score: 0.03263313722795802
# RMSE on test set: 43281.279134
# RMSE on train set: 52824.306969
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Carbon', 'Month_01')
# R-squared Score: 0.047521480009801276
# RMSE on test set: 43195.936366
# RMSE on train set: 52853.859122
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Carbon', 'Month_02')
# R-squared Score: 0.03364100821219507
# RMSE on test set: 43173.272874
# RMSE on train set: 52768.263203
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Carbon', 'Month_12')
# R-squared Score: 0.06488858669888808
# RMSE on test set: 43079.997907
# RMSE on train set: 52763.171890
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Carbon', 'alk/sal')
# R-squared Score: 0.03380471782177208
# RMSE on test set: 43313.798401
# RMSE on train set: 52871.594793
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Precipitation', 'Month_01')
# R-squared Score: 0.01748668453511726
# RMSE on test set: 43288.558075
# RMSE on train set: 52901.571959
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Precipitation', 'Month_02')
# R-squared Score: 0.002381614554348155
# RMSE on test set: 43529.131069
# RMSE on train set: 53055.305998
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Precipitation', 'Month_12')
# R-squared Score: 0.02451349737500985
# RMSE on test set: 43318.488013
# RMSE on train set: 52933.132818
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Precipitation', 'alk/sal')
# R-squared Score: 0.01613610090034967
# RMSE on test set: 43287.077355
# RMSE on train set: 52781.982924
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Month_01', 'Month_02')
# R-squared Score: 0.019493235429475786
# RMSE on test set: 43251.631355
# RMSE on train set: 52894.889505
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Month_01', 'Month_12')
# R-squared Score: 0.018546559227799353
# RMSE on test set: 43401.552922
# RMSE on train set: 53052.232122
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Month_01', 'alk/sal')
# R-squared Score: 0.035725651541031356
# RMSE on test set: 43218.413654
# RMSE on train set: 52802.461581
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Month_02', 'Month_12')
# ...
# Best Features for max r2: ('Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_12', 'alk/sal')
# R-squared Score: 0.013159561265727926
# RMSE on test set: 42838.923834
# RMSE on train set: 51038.942354
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.0029897337953710412
# RMSE on test set: 46012.136843
# RMSE on train set: 50068.854503
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.019331810429332408
# RMSE on test set: 42783.877917
# RMSE on train set: 51050.758214
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.041330829824166804
# RMSE on test set: 42806.233137
# RMSE on train set: 50970.090522
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.03802083629489861
# RMSE on test set: 42951.795728
# RMSE on train set: 50970.090522
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.035988326661365755
# RMSE on test set: 43585.317773
# RMSE on train set: 51033.188370
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.015014748685310164
# RMSE on test set: 43170.769350
# RMSE on train set: 51462.160832
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.026910026237911944
# RMSE on test set: 43189.487054
# RMSE on train set: 51097.351878
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.015394384136378059
# RMSE on test set: 43211.948201
# RMSE on train set: 51097.351878
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.03758661202618152
# RMSE on test set: 43160.566141
# RMSE on train set: 51069.729515
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.049161966971686955
# RMSE on test set: 42427.175328
# RMSE on train set: 51224.132815
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.021781851287215992
# RMSE on test set: 42672.423281
# RMSE on train set: 51249.981461
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.013080966963958107
# RMSE on test set: 42814.154802
# RMSE on train set: 51130.842563
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.017771629029955438
# RMSE on test set: 42946.565089
# RMSE on train set: 51130.842563
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.0031010420740276157
# RMSE on test set: 47982.844877
# RMSE on train set: 49034.521296
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.019665115151399015
# RMSE on test set: 43190.115124
# RMSE on train set: 51152.371426
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.0051450636465502075
# RMSE on test set: 42908.533731
# RMSE on train set: 50961.173891
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.019264103914103714
# RMSE on test set: 42887.605425
# RMSE on train set: 50697.333659
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.016885031814540485
# RMSE on test set: 42559.634434
# RMSE on train set: 51443.167267
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'alk/sal')
# R-squared Score: 0.01666339388935989
# RMSE on test set: 42971.096385
# RMSE on train set: 50404.326811
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.01693670846291584
# RMSE on test set: 42520.410465
# RMSE on train set: 51443.167267
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.010430921948279548
# RMSE on test set: 43009.910202
# RMSE on train set: 50098.582642
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.01140316729198565
# RMSE on test set: 42412.145318
# RMSE on train set: 51378.106830
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.006764670434011855
# RMSE on test set: 42874.974336
# RMSE on train set: 50025.615271
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.02136890673064762
# RMSE on test set: 42747.171892
# RMSE on train set: 50025.615271
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.01001337699666971
# RMSE on test set: 42535.347807
# RMSE on train set: 51560.600533
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.01581753805983166
# RMSE on test set: 42558.560921
# RMSE on train set: 51460.119400
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.019475166476983774
# RMSE on test set: 42575.645414
# RMSE on train set: 51460.119400
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.036419772460450806
# RMSE on test set: 42618.156473
# RMSE on train set: 51515.147088
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.0010724962991837117
# RMSE on test set: 43371.127620
# RMSE on train set: 51528.898797
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.003978127370199647
# RMSE on test set: 42873.373124
# RMSE on train set: 51533.936237
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.011709063659757102
# RMSE on test set: 43199.919219
# RMSE on train set: 49975.903840
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.009254249372000367
# RMSE on test set: 42643.076014
# RMSE on train set: 51618.597103
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.05209533937353539
# RMSE on test set: 42259.698652
# RMSE on train set: 51392.698972
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.016434266855126833
# RMSE on test set: 42715.731051
# RMSE on train set: 51254.406557
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.023778556790891914
# RMSE on test set: 42474.618684
# RMSE on train set: 51165.278785
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.014506249523928316
# RMSE on test set: 42626.514234
# RMSE on train set: 51165.278785
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.03716924437344371
# RMSE on test set: 42786.669553
# RMSE on train set: 50111.693031
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.018558961603823865
# RMSE on test set: 42703.355803
# RMSE on train set: 51158.489282
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.004159209726527835
# RMSE on test set: 42728.351322
# RMSE on train set: 50345.623803
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.007442496306308111
# RMSE on test set: 42520.654785
# RMSE on train set: 51461.308918
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.003186410101596926
# RMSE on test set: 42518.557498
# RMSE on train set: 51461.308918
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.008388189904563803
# RMSE on test set: 42680.633779
# RMSE on train set: 51624.425275
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.005690507514012788
# RMSE on test set: 42634.222852
# RMSE on train set: 51266.025037
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.0015305508144499713
# RMSE on test set: 42467.597753
# RMSE on train set: 49438.042638
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.007558690206302288
# RMSE on test set: 48052.051923
# RMSE on train set: 48174.998067
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.032429430321312624
# RMSE on test set: 42574.030853
# RMSE on train set: 49173.728893
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.019200179731727718
# RMSE on test set: 42471.815621
# RMSE on train set: 49173.728893
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.009574235506661921
# RMSE on test set: 42768.177300
# RMSE on train set: 49241.253850
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.013378874239398986
# RMSE on test set: 42580.312341
# RMSE on train set: 49599.210456
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.009409504671866187
# RMSE on test set: 42300.748407
# RMSE on train set: 49562.248643
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.008105345330885472
# RMSE on test set: 45848.982260
# RMSE on train set: 49981.584546
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.016961313364265984
# RMSE on test set: 42481.150952
# RMSE on train set: 49181.089900
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.025143978873592987
# RMSE on test set: 42394.055719
# RMSE on train set: 50618.616129
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.010023891203783664
# RMSE on test set: 42694.127856
# RMSE on train set: 50739.090863
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.015562453861553749
# RMSE on test set: 43063.981359
# RMSE on train set: 50328.920300
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.0012436028982399927
# RMSE on test set: 42917.238985
# RMSE on train set: 49958.682316
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Sodium', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.08722487224807418
# RMSE on test set: 42510.318720
# RMSE on train set: 52097.609083
# ----------------------------------------------

# %%
#ReandomForest specific features
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from itertools import combinations

# Define the target variable and the features you want to use for prediction
target = 'Power (J)mean'
all_features = ['Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12']

max_r2 = 0
best_features = []

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df[list(all_features)], np.log(df[target]), test_size=0.3, random_state=42)

# Create a random forest regression model
model = RandomForestRegressor(n_estimators=100, max_depth=9)

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model's performance using R-squared metric
r2 = r2_score(y_test, y_pred)
rmse_test = np.sqrt(mean_squared_error(np.exp(y_test), np.exp(y_pred)))
y_pred_train = model.predict(X_train)
rmse_train = np.sqrt(mean_squared_error(np.exp(y_train), np.exp(y_pred_train)))

if r2 > max_r2:
    max_r2 = r2
    best_features = all_features
    best_rmse = rmse_test
    best_rmse_train = rmse_train

print("Best Features for max r2:", best_features)
print("R-squared Score:", max_r2)
print("RMSE on test set: {:.6f}".format(best_rmse))
print("RMSE on train set: {:.6f}".format(best_rmse_train))
print("----------------------------------------------")
# Out:
# Best Features for max r2: ['Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12']
# R-squared Score: 0.1526805702965478
# RMSE on test set: 41982.678184
# RMSE on train set: 50335.629349
# ----------------------------------------------

# %%
#RandomForest only combinations of 9 features or more

from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from itertools import combinations

# Define the target variable and the features you want to use for prediction
target = 'Power (J)mean'
all_features = ['Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation','Month_01','Month_02','Month_12','alk/sal']

max_r2 = 0
best_features = []

# Generate all possible combinations of features
for r in range(9, len(all_features) + 1):
    feature_combinations = combinations(all_features, r)
    for features in feature_combinations:
        # Split the data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(df[list(features)], np.log(df[target]), test_size=0.3, random_state=42)

        # Create a random forest regression model
        model = RandomForestRegressor(n_estimators=100, max_depth=r)

        # Fit the model to the training data
        model.fit(X_train, y_train)

        # Make predictions on the test data
        y_pred = model.predict(X_test)

        # Evaluate the model's performance using R-squared metric
        r2 = r2_score(y_test, y_pred)
        rmse_test = np.sqrt(mean_squared_error(np.exp(y_test), np.exp(y_pred)))
        y_pred_train = model.predict(X_train)
        rmse_train = np.sqrt(mean_squared_error(np.exp(y_train), np.exp(y_pred_train)))

        if r2 > 0.01:
            print("Best Features for max r2:", features)
            print("R-squared Score:", r2)
            print("RMSE on test set: {:.6f}".format(rmse_test))
            print("RMSE on train set: {:.6f}".format(rmse_train))
            print("+++++++++++++++++++++++++++++++++++++++++++++++")

        if r2 > max_r2:
            max_r2 = r2
            best_features = features
            best_rmse = rmse_test
            best_rmse_train = rmse_train

print("Best Features for max r2:", best_features)
print("R-squared Score:", max_r2)
print("RMSE on test set: {:.6f}".format(best_rmse))
print("RMSE on train set: {:.6f}".format(best_rmse_train))
print("----------------------------------------------")
# Out:
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01')
# R-squared Score: 0.13255673337318774
# RMSE on test set: 42238.563293
# RMSE on train set: 50874.870589
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02')
# R-squared Score: 0.1275179961056533
# RMSE on test set: 42343.732241
# RMSE on train set: 50927.455624
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_12')
# R-squared Score: 0.14099829955340482
# RMSE on test set: 42142.994192
# RMSE on train set: 50920.350172
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'alk/sal')
# R-squared Score: 0.1284602586414444
# RMSE on test set: 42408.691973
# RMSE on train set: 50827.318251
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02')
# R-squared Score: 0.12208846474769708
# RMSE on test set: 42274.664027
# RMSE on train set: 50878.260651
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_12')
# R-squared Score: 0.13371572337048
# RMSE on test set: 42287.282696
# RMSE on train set: 50904.108398
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'alk/sal')
# R-squared Score: 0.12475575719048682
# RMSE on test set: 42423.520283
# RMSE on train set: 50697.904089
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_02', 'Month_12')
# R-squared Score: 0.1339830035735008
# RMSE on test set: 42307.083518
# RMSE on train set: 50872.079767
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_02', 'alk/sal')
# R-squared Score: 0.11329580238097281
# RMSE on test set: 42524.662005
# RMSE on train set: 50744.196885
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_12', 'alk/sal')
# R-squared Score: 0.11943412826284361
# RMSE on test set: 42405.787217
# RMSE on train set: 50905.625475
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.12524756785239777
# RMSE on test set: 42217.501612
# RMSE on train set: 50875.076597
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.12813343192349924
# RMSE on test set: 42225.548407
# RMSE on train set: 51030.821419
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'alk/sal')
# R-squared Score: 0.12617600649995642
# RMSE on test set: 42330.644396
# RMSE on train set: 50847.413260
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.1240509845887805
# RMSE on test set: 42274.141409
# RMSE on train set: 50984.442642
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_02', 'alk/sal')
# R-squared Score: 0.11592826419949187
# RMSE on test set: 42467.032180
# RMSE on train set: 51040.251656
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_12', 'alk/sal')
# R-squared Score: 0.1252733419464428
# RMSE on test set: 42363.764534
# RMSE on train set: 50833.321261
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.1243419902512678
# RMSE on test set: 42322.864390
# RMSE on train set: 50867.725746
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.10790827400927372
# RMSE on test set: 42438.506418
# RMSE on train set: 50750.379638
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.10950797906119758
# RMSE on test set: 42471.011764
# RMSE on train set: 50801.274911
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11451252668645617
# RMSE on test set: 42424.331655
# RMSE on train set: 50732.636554
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.13513423867350094
# RMSE on test set: 42178.751195
# RMSE on train set: 50886.017879
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.1399673235927259
# RMSE on test set: 42116.918669
# RMSE on train set: 50986.539507
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'alk/sal')
# R-squared Score: 0.133434565022718
# RMSE on test set: 42313.615706
# RMSE on train set: 50721.284261
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.14387100790908647
# RMSE on test set: 42065.296109
# RMSE on train set: 50691.272858
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'alk/sal')
# R-squared Score: 0.12959828542537333
# RMSE on test set: 42363.129239
# RMSE on train set: 50790.618987
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_12', 'alk/sal')
# R-squared Score: 0.1345919148719319
# RMSE on test set: 42197.019287
# RMSE on train set: 50713.385998
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.13053311363555165
# RMSE on test set: 42272.736600
# RMSE on train set: 50956.715635
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.1179925084697725
# RMSE on test set: 42384.778068
# RMSE on train set: 50698.495625
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12076864527075326
# RMSE on test set: 42400.188522
# RMSE on train set: 50779.661720
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12343976568011528
# RMSE on test set: 42371.714125
# RMSE on train set: 50716.025212
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.1195501754077487
# RMSE on test set: 42287.445616
# RMSE on train set: 50971.358268
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.12536921571291237
# RMSE on test set: 42232.785855
# RMSE on train set: 50438.275538
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.1279007201079514
# RMSE on test set: 42243.324413
# RMSE on train set: 50696.509539
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12508329919227568
# RMSE on test set: 42239.118328
# RMSE on train set: 50616.805435
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'pH', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10226840348116906
# RMSE on test set: 42500.734817
# RMSE on train set: 50711.211191
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.13690732229624447
# RMSE on test set: 42165.432237
# RMSE on train set: 50895.525624
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.12397253530699437
# RMSE on test set: 42206.149480
# RMSE on train set: 51040.211841
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'alk/sal')
# R-squared Score: 0.12933981279645168
# RMSE on test set: 42279.481478
# RMSE on train set: 50789.613203
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.12364024622785164
# RMSE on test set: 42208.159325
# RMSE on train set: 51048.048046
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'alk/sal')
# R-squared Score: 0.11824601082248742
# RMSE on test set: 42447.290916
# RMSE on train set: 50917.093497
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_12', 'alk/sal')
# R-squared Score: 0.12140387673732866
# RMSE on test set: 42295.650607
# RMSE on train set: 50958.088282
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.11670825665427942
# RMSE on test set: 42367.648880
# RMSE on train set: 51110.062408
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.11362617947350995
# RMSE on test set: 42353.485810
# RMSE on train set: 50736.369728
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.10875155814908055
# RMSE on test set: 42433.633392
# RMSE on train set: 51008.169797
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10782787469344213
# RMSE on test set: 42403.055726
# RMSE on train set: 50915.980288
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.11309476580611821
# RMSE on test set: 42317.282754
# RMSE on train set: 51149.725133
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.12400478548803662
# RMSE on test set: 42255.621346
# RMSE on train set: 50665.382198
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.11014120614421719
# RMSE on test set: 42307.328108
# RMSE on train set: 50870.951153
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11230516206861607
# RMSE on test set: 42348.805673
# RMSE on train set: 50908.900242
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.08635668754717818
# RMSE on test set: 42569.065985
# RMSE on train set: 50936.591776
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.12429287446170623
# RMSE on test set: 42178.902825
# RMSE on train set: 51063.938234
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.12747427640642917
# RMSE on test set: 42186.084830
# RMSE on train set: 50745.195838
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12636586674466965
# RMSE on test set: 42247.443356
# RMSE on train set: 51001.028296
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12025791940924246
# RMSE on test set: 42277.527307
# RMSE on train set: 50951.292781
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10634371707004708
# RMSE on test set: 42437.990654
# RMSE on train set: 51027.533092
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Temperature', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11569489988725834
# RMSE on test set: 42292.967622
# RMSE on train set: 50831.622124
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.13435108851721478
# RMSE on test set: 42275.403945
# RMSE on train set: 50923.431095
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.1434230144726938
# RMSE on test set: 42121.079784
# RMSE on train set: 50881.080707
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'alk/sal')
# R-squared Score: 0.13393464386548926
# RMSE on test set: 42349.082253
# RMSE on train set: 50884.744254
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.1429245025312995
# RMSE on test set: 42106.950088
# RMSE on train set: 50845.256593
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'alk/sal')
# R-squared Score: 0.13218029988533264
# RMSE on test set: 42399.119568
# RMSE on train set: 50916.651711
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_12', 'alk/sal')
# R-squared Score: 0.13978439145457422
# RMSE on test set: 42197.138877
# RMSE on train set: 50740.009261
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.1352641545979415
# RMSE on test set: 42288.274563
# RMSE on train set: 50781.795370
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.11891373591343068
# RMSE on test set: 42447.162427
# RMSE on train set: 50810.828830
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12326804006429226
# RMSE on test set: 42428.601665
# RMSE on train set: 50839.926508
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1247231773620816
# RMSE on test set: 42417.427695
# RMSE on train set: 50838.876658
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.12053999595383968
# RMSE on test set: 42271.010192
# RMSE on train set: 50904.221411
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.12873702711189028
# RMSE on test set: 42329.575623
# RMSE on train set: 50820.776778
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12806630837976662
# RMSE on test set: 42243.075973
# RMSE on train set: 50743.569314
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12703907284006544
# RMSE on test set: 42234.016447
# RMSE on train set: 50657.998162
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Alkalinity', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10686185968672657
# RMSE on test set: 42513.239307
# RMSE on train set: 50819.583781
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.13829415595574712
# RMSE on test set: 42122.702759
# RMSE on train set: 50886.446489
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.13348749762256962
# RMSE on test set: 42279.923931
# RMSE on train set: 50854.216272
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.13706515653267493
# RMSE on test set: 42190.436961
# RMSE on train set: 50834.978758
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1329734251969218
# RMSE on test set: 42185.807168
# RMSE on train set: 50773.360775
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1255707943221377
# RMSE on test set: 42417.162061
# RMSE on train set: 50759.684612
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'pH', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12633350012066913
# RMSE on test set: 42241.030304
# RMSE on train set: 50559.819336
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.11947432402653857
# RMSE on test set: 42270.047804
# RMSE on train set: 51045.237102
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.11992435583019345
# RMSE on test set: 42179.838282
# RMSE on train set: 50763.184824
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12537654469171977
# RMSE on test set: 42278.962169
# RMSE on train set: 50929.147873
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11850576130864676
# RMSE on test set: 42266.662648
# RMSE on train set: 50963.580215
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10957380921824711
# RMSE on test set: 42488.309685
# RMSE on train set: 50887.504240
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10988807177550086
# RMSE on test set: 42355.302365
# RMSE on train set: 50901.430366
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Sodium', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1189695361720724
# RMSE on test set: 42272.415457
# RMSE on train set: 50877.832372
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.1310481872624153
# RMSE on test set: 42203.246800
# RMSE on train set: 50874.719235
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.13609639846525512
# RMSE on test set: 42176.012470
# RMSE on train set: 50812.338719
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'alk/sal')
# R-squared Score: 0.134121555530212
# RMSE on test set: 42304.050664
# RMSE on train set: 50698.831399
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.13723124413904575
# RMSE on test set: 42213.367663
# RMSE on train set: 50926.610041
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'alk/sal')
# R-squared Score: 0.1258290947581604
# RMSE on test set: 42432.812005
# RMSE on train set: 50855.635732
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_12', 'alk/sal')
# R-squared Score: 0.137552159011595
# RMSE on test set: 42209.628542
# RMSE on train set: 50821.653124
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.13227069394601876
# RMSE on test set: 42308.265454
# RMSE on train set: 50964.597466
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.11614785042798514
# RMSE on test set: 42439.571599
# RMSE on train set: 50738.699497
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12601324980162432
# RMSE on test set: 42364.406912
# RMSE on train set: 50733.253693
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1265547996094636
# RMSE on test set: 42395.290824
# RMSE on train set: 50630.299288
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.11535765121139308
# RMSE on test set: 42320.681999
# RMSE on train set: 50914.456678
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.1285666349154343
# RMSE on test set: 42227.209464
# RMSE on train set: 50735.209204
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12509481956804103
# RMSE on test set: 42315.959673
# RMSE on train set: 50778.864145
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12593938991745068
# RMSE on test set: 42274.440655
# RMSE on train set: 50689.977925
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Alkalinity', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10950898221215599
# RMSE on test set: 42495.100769
# RMSE on train set: 50739.233374
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.13440330879894014
# RMSE on test set: 42123.423391
# RMSE on train set: 50841.346638
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.13383056834552598
# RMSE on test set: 42248.756377
# RMSE on train set: 50735.897320
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.13100873553680936
# RMSE on test set: 42227.507064
# RMSE on train set: 50795.702740
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1316721782796314
# RMSE on test set: 42198.900800
# RMSE on train set: 50763.590917
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12177421163271807
# RMSE on test set: 42419.806338
# RMSE on train set: 50775.145065
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'pH', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11058098856760012
# RMSE on test set: 42387.109795
# RMSE on train set: 50261.152478
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.12028359484231022
# RMSE on test set: 42270.466651
# RMSE on train set: 50980.714045
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.1291833306345993
# RMSE on test set: 42231.067579
# RMSE on train set: 50698.114393
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12506191741435113
# RMSE on test set: 42286.493287
# RMSE on train set: 50929.261435
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12293519933678632
# RMSE on test set: 42315.682087
# RMSE on train set: 50950.742219
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10671502424797263
# RMSE on test set: 42475.025507
# RMSE on train set: 50935.938963
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1124381221848576
# RMSE on test set: 42340.610048
# RMSE on train set: 50834.586554
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11996218201665143
# RMSE on test set: 42260.506990
# RMSE on train set: 50969.231316
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.1326192683218702
# RMSE on test set: 42189.886904
# RMSE on train set: 50781.583242
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.12857554617506828
# RMSE on test set: 42354.068295
# RMSE on train set: 50778.895447
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.1327538210741902
# RMSE on test set: 42210.405549
# RMSE on train set: 50784.654523
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.13433750169196157
# RMSE on test set: 42267.775953
# RMSE on train set: 50703.196391
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12680983625134723
# RMSE on test set: 42384.213334
# RMSE on train set: 50712.721505
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11974278551678263
# RMSE on test set: 42318.772208
# RMSE on train set: 50584.348696
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.13003382854226142
# RMSE on test set: 42217.540860
# RMSE on train set: 50751.463561
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11772808427194459
# RMSE on test set: 42347.286435
# RMSE on train set: 50905.543862
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.1255024613482475
# RMSE on test set: 42178.878095
# RMSE on train set: 50877.287864
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.13509188581670561
# RMSE on test set: 42148.356309
# RMSE on train set: 50986.425566
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'alk/sal')
# R-squared Score: 0.1217096665207521
# RMSE on test set: 42333.054301
# RMSE on train set: 50860.764791
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.13342632850158076
# RMSE on test set: 42126.536387
# RMSE on train set: 50882.444142
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'alk/sal')
# R-squared Score: 0.12179386385797508
# RMSE on test set: 42411.693898
# RMSE on train set: 50887.297464
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_12', 'alk/sal')
# R-squared Score: 0.128508872140639
# RMSE on test set: 42225.491651
# RMSE on train set: 50912.296306
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.12402143936826227
# RMSE on test set: 42299.063518
# RMSE on train set: 50967.174650
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.11300393706683054
# RMSE on test set: 42398.675661
# RMSE on train set: 50706.673650
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12024115921419354
# RMSE on test set: 42372.993580
# RMSE on train set: 50810.231333
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11925204659921662
# RMSE on test set: 42378.955890
# RMSE on train set: 50833.365686
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.12049800254341914
# RMSE on test set: 42252.892126
# RMSE on train set: 51009.353341
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.11893094731541809
# RMSE on test set: 42293.355605
# RMSE on train set: 50790.671224
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.11790801429322262
# RMSE on test set: 42305.144248
# RMSE on train set: 50779.019707
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12129228486386434
# RMSE on test set: 42284.089205
# RMSE on train set: 50821.381193
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.09761375401810357
# RMSE on test set: 42502.271484
# RMSE on train set: 50757.833928
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.13030497302406907
# RMSE on test set: 42094.267431
# RMSE on train set: 50884.142966
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.1245616203234493
# RMSE on test set: 42338.198641
# RMSE on train set: 50817.593810
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.13308431590869396
# RMSE on test set: 42181.699915
# RMSE on train set: 50832.383923
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12798503286663565
# RMSE on test set: 42192.427552
# RMSE on train set: 50820.692214
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11846467117473725
# RMSE on test set: 42360.948852
# RMSE on train set: 50765.512122
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'pH', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11525362969849451
# RMSE on test set: 42268.558829
# RMSE on train set: 50592.910905
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.11768096605202205
# RMSE on test set: 42218.421168
# RMSE on train set: 51138.682038
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.11723689272811155
# RMSE on test set: 42212.805602
# RMSE on train set: 50834.496199
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.11984995246906172
# RMSE on test set: 42294.541268
# RMSE on train set: 51043.001353
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11707161015118228
# RMSE on test set: 42240.790808
# RMSE on train set: 50991.017008
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.09944796658097554
# RMSE on test set: 42460.355108
# RMSE on train set: 51023.606785
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.10099989726784442
# RMSE on test set: 42370.106475
# RMSE on train set: 50955.918010
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11231857442351412
# RMSE on test set: 42245.112111
# RMSE on train set: 50827.079642
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.13333027359269378
# RMSE on test set: 42158.840314
# RMSE on train set: 50955.058265
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.1268387728800292
# RMSE on test set: 42319.079833
# RMSE on train set: 50801.801546
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.1319420999091082
# RMSE on test set: 42196.671575
# RMSE on train set: 50856.561733
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.13256605194434157
# RMSE on test set: 42161.130684
# RMSE on train set: 50825.143865
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1149873503447103
# RMSE on test set: 42409.589017
# RMSE on train set: 50864.214585
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1177985472408265
# RMSE on test set: 42289.831575
# RMSE on train set: 50725.513298
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1252752601891537
# RMSE on test set: 42204.432748
# RMSE on train set: 50851.437808
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Sodium', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12056816518114977
# RMSE on test set: 42303.157694
# RMSE on train set: 50970.469936
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.12662644079408314
# RMSE on test set: 42177.276972
# RMSE on train set: 50955.612923
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.12459579562901679
# RMSE on test set: 42269.833695
# RMSE on train set: 50737.049256
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.13016790835406955
# RMSE on test set: 42266.021531
# RMSE on train set: 50897.924497
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.13097996080161134
# RMSE on test set: 42177.760479
# RMSE on train set: 50839.278543
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11785484712499594
# RMSE on test set: 42404.742285
# RMSE on train set: 50887.152460
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11343427880078594
# RMSE on test set: 42305.049749
# RMSE on train set: 50707.135977
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12699209951743284
# RMSE on test set: 42210.852265
# RMSE on train set: 50814.375618
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11587123621741724
# RMSE on test set: 42268.853150
# RMSE on train set: 51076.477224
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1279642630976351
# RMSE on test set: 42182.104956
# RMSE on train set: 50827.841857
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.13444458455963615
# RMSE on test set: 42214.826012
# RMSE on train set: 50815.350574
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.14042764307399047
# RMSE on test set: 42144.867093
# RMSE on train set: 50949.096879
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'alk/sal')
# R-squared Score: 0.13313002873891788
# RMSE on test set: 42263.740395
# RMSE on train set: 50762.703488
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.1399516844567662
# RMSE on test set: 42119.907822
# RMSE on train set: 51027.239163
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'alk/sal')
# R-squared Score: 0.12502615065574152
# RMSE on test set: 42434.449893
# RMSE on train set: 50794.241718
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_12', 'alk/sal')
# R-squared Score: 0.1346753960254552
# RMSE on test set: 42228.772113
# RMSE on train set: 50903.721847
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.11809774627090064
# RMSE on test set: 42329.361258
# RMSE on train set: 51071.426109
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.11344478422825577
# RMSE on test set: 42437.452938
# RMSE on train set: 50639.705694
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.11716392602406145
# RMSE on test set: 42414.364695
# RMSE on train set: 50866.650603
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11612270166301697
# RMSE on test set: 42443.304311
# RMSE on train set: 50844.957658
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.1270295596044856
# RMSE on test set: 42248.269124
# RMSE on train set: 50998.564536
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.13058538178909773
# RMSE on test set: 42275.122266
# RMSE on train set: 50774.561782
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12999114512615784
# RMSE on test set: 42265.543039
# RMSE on train set: 50801.662075
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1288820928958484
# RMSE on test set: 42274.354359
# RMSE on train set: 50699.918993
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Alkalinity', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.09867271466580618
# RMSE on test set: 42533.351279
# RMSE on train set: 50830.677952
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.13788795226511508
# RMSE on test set: 42130.238273
# RMSE on train set: 50877.560205
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.13576700351901683
# RMSE on test set: 42213.499477
# RMSE on train set: 50737.196568
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.13509378083834445
# RMSE on test set: 42239.272226
# RMSE on train set: 50755.117189
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1347136553080316
# RMSE on test set: 42181.107390
# RMSE on train set: 50658.481368
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11540308542814004
# RMSE on test set: 42467.234177
# RMSE on train set: 50792.330725
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'pH', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12205719951382965
# RMSE on test set: 42277.358028
# RMSE on train set: 50636.793616
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.12647531330843664
# RMSE on test set: 42238.654974
# RMSE on train set: 51041.643421
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.1307351648162337
# RMSE on test set: 42174.525775
# RMSE on train set: 50689.639129
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.12315802356187289
# RMSE on test set: 42318.866105
# RMSE on train set: 50994.128230
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12667419563551385
# RMSE on test set: 42262.354377
# RMSE on train set: 50973.196348
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.09915085306161042
# RMSE on test set: 42462.293038
# RMSE on train set: 51072.204352
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11279405587079572
# RMSE on test set: 42367.163781
# RMSE on train set: 50798.328553
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Temperature', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12445458667396503
# RMSE on test set: 42253.732707
# RMSE on train set: 50898.262126
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.14103837346260495
# RMSE on test set: 42117.179716
# RMSE on train set: 50905.726287
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'alk/sal')
# R-squared Score: 0.13542352948908187
# RMSE on test set: 42324.240742
# RMSE on train set: 50810.481151
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12', 'alk/sal')
# R-squared Score: 0.1386337817248645
# RMSE on test set: 42220.207149
# RMSE on train set: 50784.923764
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.13192893024822638
# RMSE on test set: 42221.108010
# RMSE on train set: 50799.227593
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Alkalinity', 'Carbon', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.11413386758471034
# RMSE on test set: 42491.203312
# RMSE on train set: 50777.630106
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Alkalinity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.12299379114291342
# RMSE on test set: 42310.370062
# RMSE on train set: 50628.015562
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'pH', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.1324960102852808
# RMSE on test set: 42230.538510
# RMSE on train set: 50776.726324
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Sodium', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12', 'alk/sal')
# R-squared Score: 0.125720631267476
# RMSE on test set: 42265.582104
# RMSE on train set: 50823.756139
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Temperature', 'pH', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.13580075143436343
# RMSE on test set: 42176.342357
# RMSE on train set: 50775.369850
# +++++++++++++++++++++++++++++++++++++++++++++++
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6116\1055009755.py in <module>
#      26
#      27         # Fit the model to the training data
# ---> 28         model.fit(X_train, y_train)
#      29
#      30         # Make predictions on the test data
#
# c:\Users\chefi\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     448             # parallel_backend contexts set at a higher level,
#     449             # since correctness does not rely on using threads.
# --> 450             trees = Parallel(
#     451                 n_jobs=self.n_jobs,
#     452                 verbose=self.verbose,
#
# c:\Users\chefi\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1086                 self._iterating = self._original_iterator is not None
#    1087
# -> 1088             while self.dispatch_one_batch(iterator):
#    1089                 pass
#    1090
#
# c:\Users\chefi\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# c:\Users\chefi\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# c:\Users\chefi\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\Users\chefi\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# c:\Users\chefi\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# c:\Users\chefi\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# c:\Users\chefi\Anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# c:\Users\chefi\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     183             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     184
# --> 185         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186     else:
#     187         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# c:\Users\chefi\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# c:\Users\chefi\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
#gradient boosting only combinations of 10 or 11 features
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from itertools import combinations

# Define the target variable and the features you want to use for prediction
target = 'Count'
all_features = ['Latitude', 'Longitude', 'Salinity', 'Temperature','Alkalinity', 'Acidity', 'Carbon', 'Precipitation','Month_01','Month_02','Month_12']

max_r2 = 0
best_features = []
best_rmse = 0
best_rmse_train = 0

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df[list(all_features)], np.log(df[target]), test_size=0.3, random_state=42)

# Create a gradient boosting regression model
model = GradientBoostingRegressor(n_estimators=30, max_depth=7)

# Loop over all possible combinations of features
for i in range(10, len(all_features) + 1):
    feature_combinations = combinations(all_features, i)
    for features in feature_combinations:
        # Fit the model to the training data
        model.fit(X_train[list(features)], y_train)

        # Make predictions on the test data
        y_pred = model.predict(X_test[list(features)])

        # Evaluate the model's performance using R-squared metric
        r2 = r2_score(y_test, y_pred)
        rmse_test = np.sqrt(mean_squared_error(np.exp(y_test), np.exp(y_pred)))
        y_pred_train = model.predict(X_train[list(features)])
        rmse_train = np.sqrt(mean_squared_error(np.exp(y_train), np.exp(y_pred_train)))

        if r2 > 0.4:
            print("Best Features for max r2:", features)
            print("R-squared Score:", r2)
            print("RMSE on test set: {:.6f}".format(rmse_test))
            print("RMSE on train set: {:.6f}".format(rmse_train))
            print("+++++++++++++++++++++++++++++++++++++++++++++++")

        if r2 > max_r2:
            max_r2 = r2
            best_features = features
            best_rmse = rmse_test
            best_rmse_train = rmse_train

print("Best Features for max r2:", best_features)
print("R-squared Score:", max_r2)
print("RMSE on test set: {:.6f}".format(best_rmse))
print("RMSE on train set: {:.6f}".format(best_rmse_train))
print("----------------------------------------------")
# Out:
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Acidity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02')
# R-squared Score: 0.48835018368992167
# RMSE on test set: 222.146001
# RMSE on train set: 194.843300
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Acidity', 'Carbon', 'Precipitation', 'Month_01', 'Month_12')
# R-squared Score: 0.47394360421853654
# RMSE on test set: 223.609744
# RMSE on train set: 196.930215
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Acidity', 'Carbon', 'Precipitation', 'Month_02', 'Month_12')
# R-squared Score: 0.47750547220721995
# RMSE on test set: 222.909676
# RMSE on train set: 196.918382
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Acidity', 'Carbon', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.42979396185934104
# RMSE on test set: 234.074135
# RMSE on train set: 210.363713
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Acidity', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.4764368861169159
# RMSE on test set: 223.171851
# RMSE on train set: 195.148124
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.49006382429894946
# RMSE on test set: 223.394413
# RMSE on train set: 197.260953
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Acidity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.4890811512054526
# RMSE on test set: 221.214548
# RMSE on train set: 191.680687
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Alkalinity', 'Acidity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.47671573674094436
# RMSE on test set: 224.750512
# RMSE on train set: 198.435009
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Temperature', 'Alkalinity', 'Acidity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.47069704398221945
# RMSE on test set: 224.121337
# RMSE on train set: 203.293507
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Salinity', 'Temperature', 'Alkalinity', 'Acidity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.4227796989713257
# RMSE on test set: 225.677891
# RMSE on train set: 197.094639
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Acidity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.40419735297548054
# RMSE on test set: 224.958708
# RMSE on train set: 193.399892
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Acidity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.47989510925233825
# RMSE on test set: 223.239240
# RMSE on train set: 195.246026
# +++++++++++++++++++++++++++++++++++++++++++++++
# Best Features for max r2: ('Latitude', 'Longitude', 'Salinity', 'Temperature', 'Alkalinity', 'Carbon', 'Precipitation', 'Month_01', 'Month_02', 'Month_12')
# R-squared Score: 0.49006382429894946
# RMSE on test set: 223.394413
# RMSE on train set: 197.260953
# ----------------------------------------------
